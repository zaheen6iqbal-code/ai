# %% [markdown]
# ## Logistic Classification:

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('Insurance Data.csv')
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               27 non-null     int64
#  1   bought_insurance  27 non-null     int64
# dtypes: int64(2)
# memory usage: 564.0 bytes

# %%
plt.scatter(df.age,df.bought_insurance, marker='+', color='blue')

# %%
#y=1/1++e**(m*x+b)    #e=Euler's Value, whereas   e=2.71828  Sigmoid(y)=1/1++e

# %%
type(df[['age']])
# Out:
# pandas.core.frame.DataFrame

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df[['age']],df.bought_insurance,test_size=0.1)  #0.1=10%

# %%
x_train
# Out:
#     age
# 0    22
# 4    46
# 7    60
# 8    62
# 6    55
# 19   18
# 26   23
# 16   25
# 12   27
# 22   40
# 15   55
# 24   50
# 9    61
# 13   29
# 21   26
# 17   58
# 23   45
# 18   19
# 11   28
# 5    56
# 10   18
# 2    47
# 20   21
# 25   54

# %%
len(x_train)
# Out:
# 24

# %%
x_test
# Out:
#     age
# 14   49
# 1    25
# 3    52

# %%
y_train
# Out:
# 0     0
# 4     1
# 7     1
# 8     1
# 6     0
# 19    0
# 26    0
# 16    1
# 12    0
# 22    1
# 15    1
# 24    1
# 9     1
# 13    0
# 21    0
# 17    1
# 23    1
# 18    0
# 11    0
# 5     1
# 10    0
# 2     1
# 20    0
# 25    1
# Name: bought_insurance, dtype: int64

# %%
y_test
# Out:
# 14    1
# 1     0
# 3     0
# Name: bought_insurance, dtype: int64

# %%
c

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict([[25.5]])
# Out:
# C:\Users\SG\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
model.score(x_test,y_test)
# Out:
# 0.9

# %%
model.predict_proba(x_test)  # proba = Probability
# Out:
# array([[9.98538201e-01, 1.46179916e-03],
#        [9.34614708e-03, 9.90653853e-01],
#        [1.44057415e-05, 9.99985594e-01],
#        [9.99942447e-01, 5.75531437e-05],
#        [1.35638700e-02, 9.86436130e-01],
#        [3.42723795e-06, 9.99996573e-01],
#        [1.23055414e-01, 8.76944586e-01],
#        [9.34815001e-03, 9.90651850e-01],
#        [4.52639266e-08, 9.99999955e-01],
#        [9.97772285e-01, 2.22771509e-03],
#        [8.91797771e-01, 1.08202229e-01],
#        [4.13694335e-03, 9.95863057e-01],
#        [8.63263711e-05, 9.99913674e-01],
#        [9.99087396e-01, 9.12604237e-04],
#        [6.41211281e-01, 3.58788719e-01],
#        [4.88111465e-06, 9.99995119e-01],
#        [5.29354892e-03, 9.94706451e-01],
#        [5.48903871e-07, 9.99999451e-01],
#        [1.80084823e-02, 9.81991518e-01],
#        [5.72418292e-05, 9.99942758e-01]])

# %%
# !pip install pandas openpyxl
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import openpyxl as xl
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df2=pd.read_excel('Weather Data.xlsx')
df2
# Out:
#      Temperature  Humidity  WindSpeed  Rainfall  Prediction
# 0           29.2      31.5        7.0       3.3           0
# 1           32.1      70.6       18.1       1.3           0
# 2           22.7      31.8        5.9       7.6           1
# 3           10.8      41.9       13.7       8.2           1
# 4           16.6      65.4       16.6       0.1           0
# ..           ...       ...        ...       ...         ...
# 195         35.0      59.9       14.9       7.6           1
# 196         18.2      80.1       19.6       3.7           1
# 197         26.5      53.0       18.6       7.6           1
# 198         36.4      81.8        7.0      11.9           1
# 199         22.4      86.1       11.1      12.3           1
#
# [200 rows x 5 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  200 non-null    float64
#  1   Humidity     200 non-null    float64
#  2   WindSpeed    200 non-null    float64
#  3   Rainfall     200 non-null    float64
#  4   Prediction   200 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
sns.pairplot(df2, vars=['Temperature','Humidity','WindSpeed','Rainfall'],hue='Prediction')

# %%
type(df2[['Prediction']])
# Out:
# pandas.core.frame.DataFrame

# %%
df2
# Out:
#      Temperature  Humidity  WindSpeed  Rainfall  Prediction
# 0           29.2      31.5        7.0       3.3           0
# 1           32.1      70.6       18.1       1.3           0
# 2           22.7      31.8        5.9       7.6           1
# 3           10.8      41.9       13.7       8.2           1
# 4           16.6      65.4       16.6       0.1           0
# ..           ...       ...        ...       ...         ...
# 195         35.0      59.9       14.9       7.6           1
# 196         18.2      80.1       19.6       3.7           1
# 197         26.5      53.0       18.6       7.6           1
# 198         36.4      81.8        7.0      11.9           1
# 199         22.4      86.1       11.1      12.3           1
#
# [200 rows x 5 columns]

# %%
df3=df2.drop('Prediction', axis="columns")

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df3,df2.Prediction,test_size=0.1)  #0.1=10%

# %%
x_train
# Out:
#      Temperature  Humidity  WindSpeed  Rainfall
# 107         32.5      76.2        3.9       6.4
# 36          22.7      42.7       11.7      10.9
# 41          35.8      34.3        6.3      10.0
# 46          22.1      50.4       17.5       3.7
# 196         18.2      80.1       19.6       3.7
# ..           ...       ...        ...       ...
# 66          35.0      72.2       13.0      14.8
# 35          24.3      63.0        6.8      13.1
# 10          31.1      32.7        6.1       4.3
# 148         16.4      77.9        8.1      13.2
# 180         12.7      87.7       17.0       8.6
#
# [180 rows x 4 columns]

# %%
x_test
# Out:
#      Temperature  Humidity  WindSpeed  Rainfall
# 16          35.3      76.6        6.1       0.5
# 168         39.7      48.3       13.2       9.1
# 182         11.2      75.4       10.5       9.8
# 103         30.2      43.5        5.6       0.4
# 44          12.9      55.9        9.6       7.0
# 149         31.0      46.6        2.2      14.2
# 117         31.2      33.9        9.3       8.1
# 99          22.9      64.8       13.8       7.0
# 53          23.7      55.4       19.2      14.9
# 0           29.2      31.5        7.0       3.3
# 145         18.1      81.1       17.0       1.3
# 42          16.4      37.9       18.8       8.6
# 133         26.9      43.1       14.6      11.5
# 178         38.3      60.0       10.9       1.2
# 89          38.9      45.9        4.0       6.5
# 28          25.0      40.7       18.4      13.1
# 22          12.7      32.8        4.0       9.4
# 31          10.0      49.4        2.4      13.9
# 21          22.0      43.2       20.0       7.6
# ...

# %%
y_train
# Out:
# 107    1
# 36     1
# 41     1
# 46     0
# 196    1
#       ..
# 66     1
# 35     1
# 10     0
# 148    1
# 180    1
# Name: Prediction, Length: 180, dtype: int64

# %%
y_test
# Out:
# 16     0
# 168    1
# 182    1
# 103    0
# 44     1
# 149    1
# 117    1
# 99     1
# 53     1
# 0      0
# 145    1
# 42     1
# 133    1
# 178    0
# 89     1
# 28     1
# 22     1
# 31     1
# 21     1
# 102    1
# Name: Prediction, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict([[32.1,70.6,18.1,1.3]])
# Out:
# C:\Users\SG\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
model.score(x_test,y_test)
# Out:
# 0.9

# %%
model.predict_proba(x_test)  # proba = Probability
# Out:
# array([[9.98538201e-01, 1.46179916e-03],
#        [9.34614708e-03, 9.90653853e-01],
#        [1.44057415e-05, 9.99985594e-01],
#        [9.99942447e-01, 5.75531437e-05],
#        [1.35638700e-02, 9.86436130e-01],
#        [3.42723795e-06, 9.99996573e-01],
#        [1.23055414e-01, 8.76944586e-01],
#        [9.34815001e-03, 9.90651850e-01],
#        [4.52639266e-08, 9.99999955e-01],
#        [9.97772285e-01, 2.22771509e-03],
#        [8.91797771e-01, 1.08202229e-01],
#        [4.13694335e-03, 9.95863057e-01],
#        [8.63263711e-05, 9.99913674e-01],
#        [9.99087396e-01, 9.12604237e-04],
#        [6.41211281e-01, 3.58788719e-01],
#        [4.88111465e-06, 9.99995119e-01],
#        [5.29354892e-03, 9.94706451e-01],
#        [5.48903871e-07, 9.99999451e-01],
#        [1.80084823e-02, 9.81991518e-01],
#        [5.72418292e-05, 9.99942758e-01]])
