# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Insurance (06.11.2025).csv')
df
# Out:
#        age     sex     bmi  children smoker     region      charges
# 0     19.0  female  27.900       0.0    yes  southwest  16884.92400
# 1     18.0    male  33.770       1.0     no  southeast   1725.55230
# 2     28.0    male  33.000       3.0     no  southeast   4449.46200
# 3     33.0    male  22.705       0.0     no  northwest  21984.47061
# 4     32.0    male  28.880       0.0     no  northwest   3866.85520
# ...    ...     ...     ...       ...    ...        ...          ...
# 1333  50.0    male  30.970       3.0     no  northwest  10600.54830
# 1334  18.0  female  31.920       0.0     no  northeast   2205.98080
# 1335  18.0  female  36.850       0.0     no  southeast   1629.83350
# 1336  21.0  female  25.800       0.0     no  southwest   2007.94500
# 1337  61.0  female     NaN       0.0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.rename(columns={'age':'Age','sex':'Sex','bmi':'BMI','children':'Children','smoker':'Smoker','region':'Region','charges':'Charges'}, inplace=True)
df
# Out:
#        Age     Sex     BMI  Children Smoker     Region      Charges
# 0     19.0  female  27.900       0.0    yes  southwest  16884.92400
# 1     18.0    male  33.770       1.0     no  southeast   1725.55230
# 2     28.0    male  33.000       3.0     no  southeast   4449.46200
# 3     33.0    male  22.705       0.0     no  northwest  21984.47061
# 4     32.0    male  28.880       0.0     no  northwest   3866.85520
# ...    ...     ...     ...       ...    ...        ...          ...
# 1333  50.0    male  30.970       3.0     no  northwest  10600.54830
# 1334  18.0  female  31.920       0.0     no  northeast   2205.98080
# 1335  18.0  female  36.850       0.0     no  southeast   1629.83350
# 1336  21.0  female  25.800       0.0     no  southwest   2007.94500
# 1337  61.0  female     NaN       0.0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       1337 non-null   float64
#  1   Sex       1338 non-null   object
#  2   BMI       1337 non-null   float64
#  3   Children  1337 non-null   float64
#  4   Smoker    1338 non-null   object
#  5   Region    1338 non-null   object
#  6   Charges   1338 non-null   float64
# dtypes: float64(4), object(3)
# memory usage: 73.3+ KB

# %%
df['Sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
df['Region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
df['Smoker'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
newdf=df[['Age','Sex','BMI','Children','Smoker','Region','Charges']]
newdf
# Out:
#        Age     Sex     BMI  Children Smoker     Region      Charges
# 0     19.0  female  27.900       0.0    yes  southwest  16884.92400
# 1     18.0    male  33.770       1.0     no  southeast   1725.55230
# 2     28.0    male  33.000       3.0     no  southeast   4449.46200
# 3     33.0    male  22.705       0.0     no  northwest  21984.47061
# 4     32.0    male  28.880       0.0     no  northwest   3866.85520
# ...    ...     ...     ...       ...    ...        ...          ...
# 1333  50.0    male  30.970       3.0     no  northwest  10600.54830
# 1334  18.0  female  31.920       0.0     no  northeast   2205.98080
# 1335  18.0  female  36.850       0.0     no  southeast   1629.83350
# 1336  21.0  female  25.800       0.0     no  southwest   2007.94500
# 1337  61.0  female     NaN       0.0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
newdf.Sex=newdf.Sex.replace('male',1)

# %%
newdf.Sex=newdf.Sex.replace('female',2)
# Out:
# C:\Users\SG\AppData\Local\Temp\ipykernel_1452\845165666.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   newdf.Sex=newdf.Sex.replace('female',2)

# %%
newdf.Region=newdf.Region.replace('southwest',1)

# %%
newdf.Region=newdf.Region.replace('southeast',2)

# %%
newdf.Region=newdf.Region.replace('northwest',3)

# %%
newdf.Region=newdf.Region.replace('northeast',4)
# Out:
# C:\Users\SG\AppData\Local\Temp\ipykernel_1452\1337631239.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   newdf.Region=newdf.Region.replace('northeast',4)

# %%
newdf.Smoker=newdf.Smoker.replace('yes',1)

# %%
newdf.Smoker=newdf.Smoker.replace('no',2)
# Out:
# C:\Users\SG\AppData\Local\Temp\ipykernel_1452\3461777644.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   newdf.Smoker=newdf.Smoker.replace('no',2)

# %%
newdf
# Out:
#        Age  Sex     BMI  Children  Smoker  Region      Charges
# 0     19.0    2  27.900       0.0       1       1  16884.92400
# 1     18.0    1  33.770       1.0       2       2   1725.55230
# 2     28.0    1  33.000       3.0       2       2   4449.46200
# 3     33.0    1  22.705       0.0       2       3  21984.47061
# 4     32.0    1  28.880       0.0       2       3   3866.85520
# ...    ...  ...     ...       ...     ...     ...          ...
# 1333  50.0    1  30.970       3.0       2       3  10600.54830
# 1334  18.0    2  31.920       0.0       2       4   2205.98080
# 1335  18.0    2  36.850       0.0       2       2   1629.83350
# 1336  21.0    2  25.800       0.0       2       1   2007.94500
# 1337  61.0    2     NaN       0.0       1       3  29141.36030
#
# [1338 rows x 7 columns]

# %%
# Creating dataset
Data = ['Age','Sex','BMI','Children','Smoker','Region']
Total = ['Charges']

# Creating color parameters
colors = ('orange', 'cyan', 'brown',
          'grey', 'indigo", 'beige','Pink')

# Wedge properties
wp = {'linewidth': 1, 'edgecolor': "green"}
plt.title(Insurance)
plt.show()
# Out:
#   Cell In[94], line 11
#     'grey', 'indigo", 'beige','Pink')
#                                    ^
# SyntaxError: unterminated string literal (detected at line 11)

# %%
newdf.groupby['Charges','Age','Sex','BMI','Children','Smoker','Region'].sum().plot(
    kind='pie',
    autopct='%1.2f%%',
    colors=['red','blue','green','orange','blue','purple'],
    wedgeprops={'linewidth':2,'edgecolor':'white'}
)
plt.title("Insurance")
plr.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 newdf.groupby['Charges','Age','Sex','BMI','Children','Smoker','Region'].sum().plot(
#       2     kind='pie',
#       3     autopct='%1.2f%%',
#       4     colors=['red','blue','green','orange','blue','purple'],
#       5     wedgeprops={'linewidth':2,'edgecolor':'white'}
#       6 )
#       7 plt.title("Insurance")
#       8 plr.show()
#
# TypeError: 'method' object is not subscriptable

# %%
sns.pairplot(newdf, vars=['Age','Sex','BMI','Children','Smoker','Region'], hue='Charges')

# %%
df.plot(kind='scatter',x='Age',y='Sex', color='black')
# Out:
# <Axes: xlabel='Age', ylabel='Sex'>
