# %% [markdown]
# ## ML

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("homeprices.csv")

# %%
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   area    5 non-null      int64
#  1   price   5 non-null      int64
# dtypes: int64(2)
# memory usage: 212.0 bytes

# %%
df.describe
# Out:
# <bound method NDFrame.describe of    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000>

# %%
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.scatter(df.price,df.area, color='red',  edgecolors="k")

# %%
# y=mx+b

# y=price 

# x=area 

# m = slop

# y = intercept

# %%
# remove index
newdf = df.drop('price', axis = 'columns')

# %%
price = df.price

# %%
reg = linear_model.LinearRegression()  Create Opde

# %%
reg.fit(newdf,price) # fEEDing oF dAR
# Out:
# LinearRegression()

# %%
reg.predict([[927448.63013699]])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# np.float64(180616.43835616432)
