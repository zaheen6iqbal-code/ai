# %% [markdown]
# ## ML

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %% [raw]
# df = pd.read_csv('TrItYz.csv')

# %%
plt.scatter(df.area,df.price,color='green')

# %%
# y=mx+b
# y= price
# x= area
# m=slope
# y intercept
df
2
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
df2 =  df.drop('price', axis='columns')

# %%
price = df.price

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(df2,price)
# Out:
# LinearRegression()

# %%
reg.predict([[5500]])
# Out:
# C:\Users\STUDENT\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([927448.63013699])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
#y = mx +b
y = 135.78*5500+180616.43835616432

# %%
y
# Out:
# 927406.4383561644

# %%
df3 = pd.read_csv('QomuCB.csv')

# %%
df3
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
reg.predict(df3)
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205, 1348390.4109589 ,
#        1144708.90410959])

# %%
df4 = reg.predict(df3)

# %%
df4
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205, 1348390.4109589 ,
#        1144708.90410959])

# %%
df3['predicted']=df4

# %%
df3
# Out:
#     area     predicted
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
df3['predicted'].astype('int')
# Out:
# 0      316404
# 1      384297
# 2      492928
# 3      661304
# 4      740061
# 5      799808
# 6      926090
# 7      650441
# 8      825607
# 9      492928
# 10    1402705
# 11    1348390
# 12    1144708
# Name: predicted, dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
import seaborn as sns

cardf = pd.read_csv('carasign.csv')

# %%
cardf
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
cardf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df3 = cardf[['horsepower','enginesize','carlength','price']]

# %%
df3.isnull().sum()
# Out:
# horsepower    0
# enginesize    0
# carlength     0
# price         0
# dtype: int64

# %%
df3 = df3.drop_duplicates(subset=['horsepower', 'enginesize','carlength'])

# %%
df4  = df3.drop('price' ,axis = 'columns')

# %%
pre = df3['price']

# %%
reg = linear_model.LinearRegression()

# %%
df4.duplicated()
# Out:
# 0      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 194    False
# 198    False
# 201    False
# 202    False
# 203    False
# Length: 119, dtype: bool

# %%
reg.fit(df4,pre)
# Out:
# LinearRegression()

# %%
reg.predict([[120,140,170]])
# Out:
# C:\Users\STUDENT\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([14995.73184691])

# %%
df3
# Out:
#      horsepower  enginesize  carlength    price
# 0           111         130      168.8  13495.0
# 2           154         152      171.2  16500.0
# 3           102         109      176.6  13950.0
# 4           115         136      176.6  17450.0
# 5           110         136      177.3  15250.0
# ..          ...         ...        ...      ...
# 194         114         141      188.8  12940.0
# 198         162         130      188.8  18420.0
# 201         160         141      188.8  19045.0
# 202         134         173      188.8  21485.0
# 203         106         145      188.8  22470.0
#
# [119 rows x 4 columns]

# %%
sns.pairplot(df3)

# %%
reg.predict([[114,141,188.8]]) #16845.0
# Out:
# C:\Users\STUDENT\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([17126.68156462])

# %%
from sklearn.metrics import r2_score

# %%
reg.predict([[111,130,168.8]]) #13495.0
# Out:
# C:\Users\STUDENT\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([13324.7789648])

# %%
df3
# Out:
#      horsepower  enginesize  carlength    price
# 0           111         130      168.8  13495.0
# 2           154         152      171.2  16500.0
# 3           102         109      176.6  13950.0
# 4           115         136      176.6  17450.0
# 5           110         136      177.3  15250.0
# ..          ...         ...        ...      ...
# 194         114         141      188.8  12940.0
# 198         162         130      188.8  18420.0
# 201         160         141      188.8  19045.0
# 202         134         173      188.8  21485.0
# 203         106         145      188.8  22470.0
#
# [119 rows x 4 columns]

# %%
reg.predict([[106,145,188.8]]) #22470.0
# Out:
# C:\Users\STUDENT\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([17176.63210937])

# %%
reg.predict([[115,136,176.6]])#15250.0
# Out:
# C:\Users\STUDENT\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([15130.28488301])

# %%
r2_score([13495.0,22470.0,15250.0], [13324.7789648,17176.63210937,15216.34632757])
# Out:
# 0.38015510429591337

# %%
df7 = reg.predict(df4)

# %%
r2_score(pre, df7)*100
# Out:
# 82.90759077531703
